# %%
import import_ipynb      #for importing other files in jupyter
import mylibrary_true_personal as ml   #for accessing library
import math             #for functions
import random as rand   #for random 
from matplotlib import pyplot as plt
# Out:
# importing Jupyter notebook from mylibrary_true_personal.ipynb

# %%
exp_2 = "1/math.sqrt((0.31/x) + 0.69*x*x)"

x_21 = []
y_21 = []
i = 1.0001
while i < 3:
    x_21.append(ml.Integral.simpson(exp_2, 1, i, 1000))
    y_21.append(i)
    i += 0.0001

plt.plot(x_21, y_21)

# %%
x_22 = []
y_22 = []
i = 0.99999
while i > 0:
    x_22.append(ml.Integral.simpson(exp_2, 1, i, 100))
    y_22.append(i)
    i -= 0.00001

x_22 = x_22[::-1]
y_22 = y_22[::-1]
plt.plot(x_22, y_22)

# %%
i = 0
while i < len(y_22):
    if round(y_22[i], 3) == 0.766:
        print(i)
        break
    i += 1
    
print(y_22[i])
print(x_22[i])
# Out:
# 76550
# 0.7655000000010672
# -0.24835345373996717

# %%
xvalues_2 = x_22 + x_21
yvalues_2 = y_22 + y_21

plt.figure(figsize=(15,7))
plt.plot(xvalues_2, yvalues_2)
plt.text(x_22[29],y_22[29],'Radiation matter equality (a ~ 0.00029)')
plt.text(x_22[76550], y_22[76550], 'Matter Lambda equality (a ~ 0.766)')
plt.xlabel("H_0(t-t_0)")
plt.ylabel("a")
# Out:
# Text(0, 0.5, 'a')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-906e6795ffff> in <module>
# ----> 1 help(matplotlib)
#
# NameError: name 'matplotlib' is not defined
