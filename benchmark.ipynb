# %%
import import_ipynb      #for importing other files in jupyter
import mylibrary_true_personal as ml   #for accessing library
import math             #for functions
import random as rand   #for random 
from matplotlib import pyplot as plt
# Out:
# importing Jupyter notebook from mylibrary_true_personal.ipynb

# %%
exp_2 = "1/math.sqrt((0.31/x) + 0.69*x*x)"

x_21 = []
y_21 = []
i = 1.001
while i < 3:
    x_21.append(ml.Integral.simpson(exp_2, 1, i, 1000))
    y_21.append(i)
    i += 0.001

plt.plot(x_21, y_21)

# %%
x_22 = []
y_22 = []
i = 0.99999
while i > 0:
    x_22.append(ml.Integral.simpson(exp_2, 1, i, 100))
    y_22.append(i)
    i -= 0.00001

x_22 = x_22[::-1]
y_22 = y_22[::-1]
plt.plot(x_22, y_22)

# %%
xvalues_2 = x_22 + x_21
yvalues_2 = y_22 + y_21
t_values_2 = [14.389*(value - xvalues_2[0]) for value in xvalues_2]

# %%
print(-1*xvalues_2[0]*14.389)
# Out:
# 13.743386752584884

# %%
i = 0
while i < len(yvalues_2):
    if round(yvalues_2[i], 5) < 0.00030 and round(yvalues_2[i], 5) > 0.00028:
        locrm = i
        print(i)
        break
    i += 1
    
print(yvalues_2[i])
print(xvalues_2[i])
# Out:
# 29
# 0.00029000000191624613
# -0.9552001370538773

# %%
i = 0
while i < len(yvalues_2):
    if round(yvalues_2[i], 3) == 0.766:
        locml = i
        break
    i += 1
    
print(yvalues_2[i])
print(xvalues_2[i])
# Out:
# 0.7655000000010672
# -0.24835345373996717

# %%
plt.figure(figsize=(10,7))
plt.grid()
plt.plot(t_values_2, yvalues_2)
plt.scatter(t_values_2[locrm], yvalues_2[locrm], color = 'blue')
plt.scatter(t_values_2[locml], yvalues_2[locml], color = 'brown')
plt.scatter(t_values_2[100000], yvalues_2[100000], color = 'red')
plt.annotate('Radiation matter equality (a ~ 0.00029)', (t_values_2[locrm], yvalues_2[locrm]), textcoords="offset points", xytext=(0,10), ha='left', size = 12)
plt.annotate('Matter lambda equality (a ~ 0.766)', (t_values_2[locml], yvalues_2[locml]), textcoords="offset points", xytext=(0,10), ha='left', size = 12)
plt.annotate('Present Universe (~13.745 Billion years)', (t_values_2[100000], yvalues_2[100000]), textcoords="offset points", xytext=(0,10), ha='left', size = 12)
plt.rc('font', size=12) 
plt.xlabel("$t$   (Billion years)")
plt.ylabel("a")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
# ...
